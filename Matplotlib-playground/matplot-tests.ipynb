# %%
from matplotlib import pyplot as plt
import random

X = ['01/24','02/24','03/24','04/24','05/24', '06/24','07/24', '08/24', '09/24']
Y = [1,145,23,78,147,300,240,78,1400]


plt.title('Number of DDOS / months')
plt.xlabel('Months')
plt.ylabel('DDOS Attacks')
plt.plot(X,Y)

# %%
plt.scatter(X,Y)
